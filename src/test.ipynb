# %%
import re
import spacy
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.neighbors import NearestNeighbors

# %%
# What is a lemma? 
# A lemma is a step past stemming in out NLP processing. It takes the meaning of the word while retaining relative juxaposition of the letters to encapsulate that meaning
# First thing we have to do is create a dataframe object
df = pd.read_csv(r'C:\Users\Alex Lucchesi\OneDrive\Desktop\bonfire-119-mongo-and-streamlit\oracle_cards.csv', low_memory=False)
df.head()
# Out:
#   object                                    id
# 0   card  86bf43b1-8d4e-4759-bb2d-0b2e03ba7012  \
# 1   card  7050735c-b232-47a6-a342-01795bfd0d46
# 2   card  e718b21b-46d1-4844-985c-52745657b1ac
# 3   card  036ef8c9-72ac-46ce-af07-83b79d736538
# 4   card  b125d1e7-5d9b-4997-88b0-71bdfc19c6f2
#
#                               oracle_id multiverse_ids  mtgo_id  mtgo_foil_id
# 0  0004ebd0-dfd6-4276-b4a6-de0003e94237        [15862]  15870.0       15871.0  \
# 1  0006faf6-7a61-426c-9034-579f2cfcfa83       [370780]  49283.0       49284.0
# 2  0007c283-5b7a-4c00-9ca1-b455c8dff8c3       [470580]  77122.0           NaN
# 3  000d5588-5a4c-434e-988d-396632ade42c        [83282]  22609.0       22610.0
# 4  000e5d65-96c3-498b-bd01-72b1a1991850        [12380]  12637.0       12638.0
#
#    tcgplayer_id  cardmarket_id                 name lang  ... frame_effects
# 0        3094.0         3081.0           Static Orb   en  ...           NaN  \
# 1       69965.0       262945.0  Sensory Deprivation   en  ...           NaN
# 2      196536.0       391692.0       Road of Return   en  ...           NaN
# 3       12835.0        12551.0           Storm Crow   en  ...           NaN
# 4        6412.0        10604.0       Walking Sponge   en  ...           NaN
#
#   tcgplayer_etched_id promo_types loyalty  life_modifier hand_modifier
# 0                 NaN         NaN     NaN            NaN           NaN  \
# 1                 NaN         NaN     NaN            NaN           NaN
# 2                 NaN         NaN     NaN            NaN           NaN
# 3                 NaN         NaN     NaN            NaN           NaN
# 4                 NaN         NaN     NaN            NaN           NaN
#
#   attraction_lights color_indicator  content_warning flavor_name
# 0               NaN             NaN              NaN         NaN
# 1               NaN             NaN              NaN         NaN
# 2               NaN             NaN              NaN         NaN
# 3               NaN             NaN              NaN         NaN
# 4               NaN             NaN              NaN         NaN
#
# [5 rows x 80 columns]

# %%
# Let's preview the column we are trying to transform!
df['oracle_text']
# Out:
# 0        As long as Static Orb is untapped, players can...
# 1         Enchant creature\nEnchanted creature gets -3/-0.
# 2        Choose one —\n• Return target permanent card f...
# 3        Flying (This creature can't be blocked except ...
# 4        {T}: Target creature loses your choice of flyi...
#                                ...
# 28924    Target creature you control gains indestructib...
# 28925    Red instant and sorcery spells you control hav...
# 28926                                                  NaN
# 28927    +1: Up to one target creature gains double str...
# 28928                      All Sliver creatures get +1/+1.
# Name: oracle_text, Length: 28929, dtype: object

# %%
# !python -m spacy download en_core_web_md
# Out:
# Collecting en-core-web-md==3.5.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_md-3
#      ------------------------------          33.0/42.8 MB 12.6 MB/s eta 0:00:01
#      ------------------------------          33.5/42.8 MB 12.6 MB/s eta 0:00:01
#      -------------------------------         34.2/42.8 MB 13.1 MB/s eta 0:00:01
#      -------------------------------         35.1/42.8 MB 13.4 MB/s eta 0:00:01
#      --------------------------------        35.9/42.8 MB 13.9 MB/s eta 0:00:01
#      ---------------------------------       36.5/42.8 MB 13.9 MB/s eta 0:00:01
#      ----------------------------------      37.3/42.8 MB 14.2 MB/s eta 0:00:01
#      ----------------------------------      38.0/42.8 MB 14.6 MB/s eta 0:00:01
#      -----------------------------------     38.7/42.8 MB 14.2 MB/s eta 0:00:01
#      -----------------------------------     39.3/42.8 MB 14.2 MB/s eta 0:00:01
#      ------------------------------------    40.0/42.8 MB 14.6 MB/s eta 0:00:01
#      -------------------------------------   40.7/42.8 MB 14.6 MB/s eta 0:00:01
#      -------------------------------------   41.4/42.8 MB 14.6 MB/s eta 0:00:01
#      --------------------------------------  42.0/42.8 MB 14.9 MB/s eta 0:00:01
#      --------------------------------------  42.6/42.8 MB 14.9 MB/s eta 0:00:01
#      --------------------------------------  42.8/42.8 MB 14.6 MB/s eta 0:00:01
#      --------------------------------------  42.8/42.8 MB 14.6 MB/s eta 0:00:01
#      --------------------------------------  42.8/42.8 MB 14.6 MB/s eta 0:00:01
#      --------------------------------------  42.8/42.8 MB 14.6 MB/s eta 0:00:01
#      --------------------------------------- 42.8/42.8 MB 11.3 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.6.0,>=3.5.0 in c:\users\alex lucchesi\appdata\local\programs\python\python311\lib\site-packages (from en-core-web-md==3.5.0) (3.5.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\alex lucchesi\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\alex lucchesi\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (1.0.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\alex lucchesi\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (1.0.9)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\alex lucchesi\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (2.0.7)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\alex lucchesi\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (3.0.8)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in c:\users\alex lucchesi\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (8.1.10)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\alex lucchesi\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (1.1.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\alex lucchesi\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (2.4.6)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\alex lucchesi\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (2.0.8)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in c:\users\alex lucchesi\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (0.7.0)
# Requirement already satisfied: pathy>=0.10.0 in c:\users\alex lucchesi\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (0.10.1)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\alex lucchesi\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (6.3.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\alex lucchesi\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (4.65.0)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\alex lucchesi\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (1.24.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\alex lucchesi\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (2.30.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in c:\users\alex lucchesi\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (1.10.7)
# Requirement already satisfied: jinja2 in c:\users\alex lucchesi\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (3.1.2)
# Requirement already satisfied: setuptools in c:\users\alex lucchesi\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\alex lucchesi\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\alex lucchesi\appdata\local\programs\python\python311\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (3.3.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\alex lucchesi\appdata\local\programs\python\python311\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\alex lucchesi\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\alex lucchesi\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\alex lucchesi\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (2.0.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\alex lucchesi\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (2023.5.7)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\alex lucchesi\appdata\local\programs\python\python311\lib\site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\alex lucchesi\appdata\local\programs\python\python311\lib\site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (0.0.4)
# Requirement already satisfied: colorama in c:\users\alex lucchesi\appdata\local\programs\python\python311\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\alex lucchesi\appdata\local\programs\python\python311\lib\site-packages (from typer<0.8.0,>=0.3.0->spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\alex lucchesi\appdata\local\programs\python\python311\lib\site-packages (from jinja2->spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (2.1.2)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_md')

# %%
# Dropping all null values from the oracle text column
df.dropna(subset=['oracle_text'], axis = 0, inplace=True)

# Dropping all values from the oracle text column that are empty
df.drop(df.index[df['oracle_text'] == ''], inplace = True)

# %%
# Using regex, we remove all non alpha-numeric values from our column before lemmatizing
df['oracle_text'] = [re.sub('[^0-9a-zA-Z]+', " ", i) for i in df.oracle_text]
df['oracle_text']
# Out:
# 0        As long as Static Orb is untapped players can ...
# 1            Enchant creature Enchanted creature gets 3 0
# 2        Choose one Return target permanent card from y...
# 3        Flying This creature can t be blocked except b...
# 4         T Target creature loses your choice of flying...
#                                ...
# 28922    When Quarry Beetle enters the battlefield you ...
# 28924    Target creature you control gains indestructib...
# 28925    Red instant and sorcery spells you control hav...
# 28927     1 Up to one target creature gains double stri...
# 28928                        All Sliver creatures get 1 1
# Name: oracle_text, Length: 26627, dtype: object

# %%
# Using spacy! First, we need instantiate the dictionary that we just downloaded
nlp = spacy.load('en_core_web_md')
lemmas = []
for doc in df['oracle_text']:
    lemmas.append([token.lemma_.lower().strip() for token in nlp(str(doc)) if (token.is_stop != True) and (token.is_punct != True) and (token.is_space != True)])
df['lemmas'] = lemmas

# %%
df
# Out:
#       object                                    id
# 0       card  86bf43b1-8d4e-4759-bb2d-0b2e03ba7012  \
# 1       card  7050735c-b232-47a6-a342-01795bfd0d46
# 2       card  e718b21b-46d1-4844-985c-52745657b1ac
# 3       card  036ef8c9-72ac-46ce-af07-83b79d736538
# 4       card  b125d1e7-5d9b-4997-88b0-71bdfc19c6f2
# ...      ...                                   ...
# 28922   card  69e11478-bfc7-4bcc-b65c-dc2d4449e99f
# 28924   card  d6695fa8-881c-407c-91d9-3ac770372d35
# 28925   card  4d5edf4f-5695-42fc-9e57-c4faef60fbc3
# 28927   card  09f06f55-7918-46c4-80ff-0bf39e091a4a
# 28928   card  000edc61-b3ae-49e3-87f4-0250fa6a4501
#
#                                   oracle_id multiverse_ids   mtgo_id
# 0      0004ebd0-dfd6-4276-b4a6-de0003e94237        [15862]   15870.0  \
# 1      0006faf6-7a61-426c-9034-579f2cfcfa83       [370780]   49283.0
# 2      0007c283-5b7a-4c00-9ca1-b455c8dff8c3       [470580]   77122.0
# 3      000d5588-5a4c-434e-988d-396632ade42c        [83282]   22609.0
# 4      000e5d65-96c3-498b-bd01-72b1a1991850        [12380]   12637.0
# ...                                     ...            ...       ...
# 28922  fff66029-24bb-4354-a650-99a205fd168f       [430816]   64738.0
# 28924  fffa9334-3576-4f70-9605-2ad062cdbc69       [430770]   64646.0
# 28925  fffaa634-42a0-4038-b027-24f28754fec7       [571548]  101914.0
# 28927  fffdc2ac-bde4-4e4c-a5bd-0e6c6e49ad91       [430833]   64772.0
# 28928  ffff90c3-63c4-4dee-a21d-6b2b113f4f80       [509409]   86451.0
#
#        mtgo_foil_id  tcgplayer_id  cardmarket_id                     name
# 0           15871.0        3094.0         3081.0               Static Orb  \
# 1           49284.0       69965.0       262945.0      Sensory Deprivation
# 2               NaN      196536.0       391692.0           Road of Return
# 3           22610.0       12835.0        12551.0               Storm Crow
# 4           12638.0        6412.0        10604.0           Walking Sponge
# ...             ...           ...            ...                      ...
# 28922       64739.0      136709.0       298854.0            Quarry Beetle
# 28924       64647.0      136683.0       298834.0         Without Weakness
# 28925           NaN      276869.0       665173.0  Firesong and Sunspeaker
# 28927       64773.0      132234.0       298282.0        Samut, the Tested
# 28928           NaN      233631.0       542666.0             Sinew Sliver
#
#       lang  ... tcgplayer_etched_id promo_types loyalty life_modifier
# 0       en  ...                 NaN         NaN     NaN           NaN  \
# 1       en  ...                 NaN         NaN     NaN           NaN
# 2       en  ...                 NaN         NaN     NaN           NaN
# 3       en  ...                 NaN         NaN     NaN           NaN
# 4       en  ...                 NaN         NaN     NaN           NaN
# ...    ...  ...                 ...         ...     ...           ...
# 28922   en  ...                 NaN         NaN     NaN           NaN
# 28924   en  ...                 NaN         NaN     NaN           NaN
# 28925   en  ...                 NaN         NaN     NaN           NaN
# 28927   en  ...                 NaN         NaN       4           NaN
# 28928   en  ...                 NaN         NaN     NaN           NaN
#
#        hand_modifier attraction_lights color_indicator content_warning
# 0                NaN               NaN             NaN             NaN  \
# 1                NaN               NaN             NaN             NaN
# 2                NaN               NaN             NaN             NaN
# 3                NaN               NaN             NaN             NaN
# 4                NaN               NaN             NaN             NaN
# ...              ...               ...             ...             ...
# 28922            NaN               NaN             NaN             NaN
# 28924            NaN               NaN             NaN             NaN
# 28925            NaN               NaN             NaN             NaN
# 28927            NaN               NaN             NaN             NaN
# 28928            NaN               NaN             NaN             NaN
#
#        flavor_name                                             lemmas
# 0              NaN  [long, static, orb, untapped, player, t, untap...
# 1              NaN  [enchant, creature, enchanted, creature, get, ...
# 2              NaN  [choose, return, target, permanent, card, grav...
# 3              NaN  [fly, creature, t, block, creature, flying, re...
# 4              NaN  [t, target, creature, lose, choice, fly, strik...
# ...            ...                                                ...
# 28922          NaN  [quarry, beetle, enter, battlefield, return, t...
# 28924          NaN  [target, creature, control, gain, indestructib...
# 28925          NaN  [red, instant, sorcery, spell, control, lifeli...
# 28927          NaN  [1, target, creature, gain, double, strike, en...
# 28928          NaN                           [sliver, creature, 1, 1]
#
# [26627 rows x 81 columns]

# %%
# Create a vectorizor to save our vocabulary and map out our lemmas to a euclidean plane

# To do so, we will create a function called dummy_fun that takes in a doc and returns it
def dummy_fun(doc):
    return doc

# Create vect:
vect = TfidfVectorizer(preprocessor=dummy_fun,
                       token_pattern=None,
                       tokenizer=dummy_fun)

# Fit the vectorizer
vect.fit(df.lemmas)
# Out:
# TfidfVectorizer(preprocessor=<function dummy_fun at 0x000001EC3FA39120>,
#                 token_pattern=None,
#                 tokenizer=<function dummy_fun at 0x000001EC3FA39120>)

# %%
# Last step for our modeling is to create a model and fit it
model = NearestNeighbors(n_neighbors=12)
model.fit(vect.transform(df.lemmas))

x, y = model.kneighbors(vect.transform(df['lemmas'][df['name'] == 'The World Tree']))
for val in y:
    display(df['name'][val])
# Out:
# 5321     Dusk Legion Duelist
# 17502       Skyline Predator
# 21721       Act of Authority
# 6563            Dimir Locket
# 14654          Myr Reservoir
# 330           Jasconian Isle
# 16177        Pterodon Knight
# 24391       Brush with Death
# 20936     Crystalline Sliver
# 9553              Blood Lust
# 11560              Persecute
# 21832      Temporal Trespass
# Name: name, dtype: object

# %%
from model import dummy_func, Model
m = Model()
m.recommended_cards('sol ring')
# Out:
# ['Sol', 'Ring']
# ['Thran', 'Dynamo']
# ["Sisay's", 'Ring']
# ["Kozilek's", 'Channeler']
# ["Ur-Golem's", 'Eye']
# ['Sunastian', 'Falconer']
# ['Weaver', 'of', 'Currents']
# ['Palladium', 'Myr']
# ['Apprentice', 'Wizard']
# ['Chromatic', 'Orrery']
# ["Ashnod's", 'Altar']
# ["Mishra's", 'Workshop']
# [<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=488x680>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=488x680>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=488x680>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=488x680>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=488x680>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=488x680>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=488x680>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=488x680>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=488x680>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=488x680>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=488x680>]
